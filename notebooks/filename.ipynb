# %%
print("return jupyter notebook")
# Out:
# return jupyter notebook

# %%
# get file JAN B1 WEEK1 2021-12-27 to 2022-01-02.xlsx 
# return a data frame

# %%
stirng = "JAN B1 WEEK1 2021-12-27 to 2022-01-02.xlsx"

# %%
all_files = []
def get_file_paths():
    return glob.glob(os.path.join(os.getcwd(), '2022', '**', '*.xlsx'), recursive=True)
sheet_name = ['MON', 'TUE', 'WED', 'THU', 'FRI','SAT', 'SUN']
files = get_file_paths()
for f in files:
    try:
        
        for sheet in sheet_name:
            df = pd.read_excel(f, sheet_name=sheet, engine='openpyxl')
            df['Day'] = sheet
