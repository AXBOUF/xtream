# %%
import pandas as pd
from IPython.display import display
pd.set_option("display.max_colwidth", None)
pd.set_option("display.expand_frame_repr", False)

df = pd.read_excel("week1.xlsx")
print(df.head())


display(df.style.set_table_styles(
    [{'selector': 'table', 'props': [('overflow-x', 'auto'), ('display', 'block')]}]
))
# Out:
#   B2 Daily Report Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...                   Unnamed: 34 Unnamed: 35 Unnamed: 36    Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41  Unnamed: 42 Unnamed: 43
# 0      29-12-2025        NaN        NaN         NaN        NaN        NaN        NaN    WEATHER        NaN      SUNNY  ...  Merchant machine usage at GA         NaN         NaN  Settle amount         NaN         NaN         NaN         NaN          NaN         NaN
# 1                        NaN        NaN         NaN        NaN        NaN        NaN        NaN        NaN        NaN  ...                           NaN         NaN         NaN            NaN         NaN         NaN         NaN         NaN          NaN         NaN
# 2              No  Docket No     Reg No      Mobile     Gender       TIME    Service       CASH       CARD        RSL  ...                           NaN         NaN  GA machine    BLH machine       Wongo         NaN         NaN  GA machine  BLH machine       Wongo
# 3               1      35497     FNY43X  0418432402          M        815     RSL/HP        NaN        NaN        160  ...                           NOV         1.0         NaN            NaN         NaN         NaN          16         NaN          NaN         NaN
# 4               2      35498     FPI84U  0403506025          F        920          X        NaN         75          0  ...                           NaN         2.0         NaN            NaN         NaN         NaN          17         NaN          NaN         NaN
#
# [5 rows x 44 columns]
